# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
lst = ['LR', 'LSTM', 'DTC', 'ETC',
            'ABC', 'GB', 'RFC']
data = {'Models':['LR', 'LSTM', 'DTC', 'ETC','ABC', 'GB', 'RFC'], 'Accuracy':[98.4,93.4,95.7,97.3,98.6,96.2,99.1]}
df = pd.DataFrame(data)
print(df)
# Out:
#   Models  Accuracy
# 0     LR      98.4
# 1   LSTM      93.4
# 2    DTC      95.7
# 3    ETC      97.3
# 4    ABC      98.6
# 5     GB      96.2
# 6    RFC      99.1

# %%
df.plot(x="Models", y="Accuracy", kind="line", figsize=(10, 9))
